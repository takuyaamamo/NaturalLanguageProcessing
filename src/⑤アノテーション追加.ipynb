# %% [markdown]
# ### アノテーション保存用のカラム追加

# %% [markdown]
# #### docsテーブル確認
#  * ディレクトリ：../../NaturalLanguageProcessing/data/sqlite3/sqlite3
#  * テーブル名：docs
#
# | #  | 項目                                        | 型                                   | 項目説明                                       |
# | -- | ------------------------------------------- | ------------------------------------ | -----------------------------------------------|
# | 1  | id                                          | INTEGER                              | 既に作成済                                     |
# | 2  | content                                     | TEXT                                 | 既に作成済                                     |
# | 3  | meta_info                                   | BLOB                                 | 既に作成済                                     |
# | 4  | sentence                                    | BLOB                                 | 既に作成済                                     |
# | 5  | chunk                                       | BLOB                                 | 既に作成済                                     |
# | 6  | token                                       | BLOB                                 | 既に作成済                                     |
# | 7  | <font color="red"><b>affiliation</b></font> | <font color="red"><b>BLOB</b></font> | <font color="red"><b>今回カラム追加</b></font> |

# %% [markdown]
# ### データベース接続の関数定義

# %%
import json
import sqlite3

conn = None

# データベース接続
def connect():
    # global変数でconnを呼び出し
    global conn
    # データベースの場所を指定
    conn = sqlite3.connect('../../NaturalLanguageProcessing/data/sqlite3/sqlite3')

# データベース接続終了
def close():
#   終了
    conn.close()

# テーブル作成
def create_table():
#   executeでSQL構文作成、docsがあれば削除
    conn.execute('DROP TABLE IF EXISTS docs')
#   docsテーブルを新規作成
    conn.execute('''CREATE TABLE docs (
            id          INTEGER PRIMARY KEY AUTOINCREMENT,
            content     TEXT,
            meta_info   BLOB,
            sentence    BLOB,
            chunk       BLOB,
            token       BLOB
        )''')

# データをインサートする
def db_load(values):
    
#   valuesに指定したパラメータ順序またはマッピングを?に入れて実行する
    conn.executemany(
        'INSERT INTO docs (content, meta_info) VALUES (?,?)',
        values)
#   確定
    conn.commit()

# 一部のデータを見る
def get(doc_id, fl):
#   .fetchone()でカーソルの次の行を取得
    row_ls = conn.execute(f"SELECT {','.join(fl)} FROM docs WHERE id = {doc_id}").fetchone()
    row_dict = {}
#   flとrow_lsで抜き出したデータをzipする
    for key, value in zip(fl, row_ls):
        row_dict[key] = value
    return row_dict

# id番号を抜き出す
def get_all_ids(limit, offset=0):
#   limitで取得上限、OFFSETで開始位置を指定してデータを抜き出す。そのデータの1番目id番号を抜き出す
    return [record[0] for record in conn.execute('SELECT id FROM docs LIMIT ? OFFSET ?', (limit, offset))]

# %% [markdown]
# #### カラム追加（affiliation）

# %%
# 作成していないときに実行
# connect()

# name = "affiliation"
# conn.execute("")
# conn.execute("ALTER TABLE docs ADD COLUMN '{0}' 'BLOB'".format(name))

# close()

# %% [markdown]
# ### 正規表現のパターンによるテキストデータの解析

# %% [markdown]
# | 記法      | 意味                                                                |
# |-----------| ------------------------------------------------------------------- |
# | `.`       | 任意の1文字                                                         |
# | `*`       | 直前の文字の0回以上の繰り返し                                       |
# | `+`       | 直前の文字の1回以上の繰り返し                                       |
# | `*?`      | 直前の文字の0回以上の繰り返し、ただし最小部分にマッチ（最小マッチ） |
# | `+?`      | 直前の文字の1回以上の繰り返し、ただし最小部分にマッチ（最小マッチ） |
# | `[^ABC]`  | A、B、C以外の1文字                                                  |

# %% [markdown]
# ### アノテーション用関数定義

# %% [markdown]
# #### アノテーションとは
#
# 正規表現のパターンを用いてテキストデータ中の名詞句に意味付けを行うこと。

# %%
# 大学・学会のアノテーションを付けるプログラム
def create_annotation(doc_id, ptn):
    # SQLiteからdoc_idに該当する行のテキストを取得
    row = get(doc_id, fl=['content'])
    text = row['content']
    annos = []
    
    for chunk in get_annotation(doc_id, 'chunk'):
        # チャンクのbeginからendまでのtextを取り出し、正規表現でマッチングをかける
        chunk_str = text[chunk['begin']:chunk['end']]
        m = ptn.search(chunk_str)
        if not m:
            continue  
        # マッチしたら開始位置と終了位置を取得
        anno = {
            'begin':    chunk['begin'] + m.start(),
            'end':      chunk['begin'] + m.end(),
        }
        print(text[anno['begin']:anno['end']])
        annos.append(anno)
    return annos

# アノテーションを設定
def set_annotation(doc_id, name, value):
#   docsのid行をwhere idで指定し、その行にname = valueのアノテーションを追加　
    conn.execute('UPDATE docs SET {0} = ? where id = ?'.format(name), (json.dumps(value), doc_id))
#   確定
    conn.commit()

# アノテーションを確認
def get_annotation(doc_id, name):
#   docsのid行をwhere idで指定しnameから取り出す
    row = conn.execute('SELECT {0} FROM docs WHERE id = ?'.format(name), (doc_id,)).fetchone()
    if row[0] is not None:
        return json.loads(row[0])
    else:
        return []

# %% [markdown]
# ### docsテーブルの「affiliation」カラムにデータ追加

# %%
import re

# dict型で大学と学会の正規表現を定義する
dic = [
    r'[^ 『（ ]+?大学',
    r'[^ 『（ ]+?学会',
    r'[^ 『（ ]+?協会',
]

# 上記dictを|でつないで正規表現としてコンパイルする。|はorとして機能する。
ptn = re.compile(r'|'.join(dic))

anno_name = 'affiliation'

connect()
for doc_id in get_all_ids(limit=-1):
    # create_annotationでアノテーションを生成
    annos = create_annotation(doc_id, ptn)
    print(annos)
    # set_annotationでSQLiteに生成したアノテーションを書き込む
    set_annotation(doc_id, anno_name, annos)
close()
# Out:
# ボリビア映画協会
# [{'begin': 8444, 'end': 8452}]
# []
# []
# 王立ブータン大学
# Bhutan,通称:カンルン大学
# [{'begin': 12587, 'end': 12595}, {'begin': 12623, 'end': 12639}]
# プラハ大学
# プラハ大学
# カレル大学
# [{'begin': 2148, 'end': 2153}, {'begin': 2242, 'end': 2247}, {'begin': 2248, 'end': 2253}]
# []
# []
# []
# チリ大学
# サンティアゴ・デ・チレ大学
# チリ・カトリック大学
# [{'begin': 22148, 'end': 22152}, {'begin': 22166, 'end': 22179}, {'begin': 22187, 'end': 22197}]
# 福島県立医科大学
# ガーナ大学
# ガーナ大学
# クマシ大学
# ケープ・コースト大学
# ガーナサッカー協会
# [{'begin': 4244, 'end': 4252}, {'begin': 4281, 'end': 4286}, {'begin': 7748, 'end': 7753}, {'begin': 7760, 'end': 7765}, {'begin': 7766, 'end': 7776}, {'begin': 9341, 'end': 9350}]
# []
# エクアドル中央大学
# グアヤキル大学
# クエンカ大学
# [{'begin': 11120, 'end': 11129}, {'begin': 11142, 'end': 11149}, {'begin': 11157, 'end': 11163}]
# 南太平洋大学
# [{'begin': 3964, 'end': 3970}]
# 日本気象協会
# 日本気象協会
# [{'begin': 15355, 'end': 15361}, {'begin': 15456, 'end': 15462}]
# []
# ブカレスト大学
# [{'begin': 5287, 'end': 5294}]
# []
# キクユ青年協会
# キクユ中央協会
# キクユ中央協会
# ナイロビ大学
# [{'begin': 1317, 'end': 1324}, {'begin': 1394, 'end': 1401}, {'begin': 1496, 'end': 1503}, {'begin': 7499, 'end': 7505}]
# ウェスタンシドニー大学
# [{'begin': 15729, 'end': 15740}]
# []
# サン・カルロス・デ・グアテマラ大学
# フランシスコ・マロキン大学
# [{'begin': 8326, 'end': 8343}, {'begin': 8350, 'end': 8363}]
# 和田春樹東京大学
# ソウル大学
# ソウル大学
# 有名大学
# 一流大学
# プリンストン大学
# 一流大学
# 一般大学
# 韓国警察研究学会
# 4位大学
# 大韓サッカー協会
# [315]、高麗大学
# 日本放送協会
# 日本放送協会
# [{'begin': 25528, 'end': 25536}, {'begin': 38011, 'end': 38016}, {'begin': 38238, 'end': 38243}, {'begin': 43864, 'end': 43868}, {'begin': 44548, 'end': 44552}, {'begin': 45242, 'end': 45250}, {'begin': 45275, 'end': 45279}, {'begin': 45637, 'end': 45641}, {'begin': 46045, 'end': 46053}, {'begin': 47866, 'end': 47870}, {'begin': 50341, 'end': 50349}, {'begin': 50748, 'end': 50758}, {'begin': 53938, 'end': 53944}, {'begin': 58902, 'end': 58908}]
# 国立大学
# [{'begin': 12457, 'end': 12461}]
# ダルエスサラーム大学
# ソコイネ農業大学
# [{'begin': 10362, 'end': 10372}, {'begin': 10373, 'end': 10381}]
# ヘブライ大学
# 弁護士協会
# ヘブライ大学
# ヨーロッパ生殖医学学会
# イスラエルサッカー協会
# [{'begin': 2973, 'end': 2979}, {'begin': 10510, 'end': 10515}, {'begin': 24354, 'end': 24360}, {'begin': 28096, 'end': 28107}, {'begin': 30521, 'end': 30532}]
# ベネズエラ中央大学
# ロス・アンデス大学
# カラボボ大学
# スリア大学
# シモン・ボリバル大学
# 日本大学
# [{'begin': 23362, 'end': 23371}, {'begin': 23379, 'end': 23388}, {'begin': 23396, 'end': 23402}, {'begin': 23403, 'end': 23408}, {'begin': 23416, 'end': 23426}, {'begin': 28818, 'end': 28822}]
# []
# ハイチ大学
# [{'begin': 10012, 'end': 10017}]
# []
# 創価学会
# ブラジル創価学会
# コインブラ大学
# 法科大学
# パラナ連邦大学
# リオデジャネイロ連邦大学
# パラナ連邦大学
# サンパウロ連邦大学
# サンパウロ大学
# [{'begin': 28127, 'end': 28131}, {'begin': 28795, 'end': 28803}, {'begin': 29060, 'end': 29067}, {'begin': 29129, 'end': 29133}, {'begin': 29190, 'end': 29197}, {'begin': 29285, 'end': 29297}, {'begin': 29317, 'end': 29324}, {'begin': 29332, 'end': 29341}, {'begin': 29349, 'end': 29356}]
# チッタゴン丘陵人民連帯連合協会
# 元ダッカ大学
# [{'begin': 3652, 'end': 3667}, {'begin': 4823, 'end': 4829}]
# 王立アジア協会
# [{'begin': 467, 'end': 474}]
# []
# []
# []
# 聖トマス・アクィナス大学
# 国公立大学
# 私立大学
# コロンビア国立大学
# ロス・アンデス大学
# アンティオキア大学
# ハベリアナ大学
# 公立大学
# [{'begin': 20851, 'end': 20863}, {'begin': 21191, 'end': 21196}, {'begin': 21200, 'end': 21204}, {'begin': 21235, 'end': 21244}, {'begin': 21254, 'end': 21263}, {'begin': 21273, 'end': 21282}, {'begin': 21292, 'end': 21299}, {'begin': 21335, 'end': 21339}]
# []
# []
# 赤道ギニア国立大学
# 国立遠隔教育大学
# [{'begin': 5056, 'end': 5065}, {'begin': 5158, 'end': 5166}]
# スイス放送協会
# [{'begin': 9978, 'end': 9985}]
# トルコ友好協会
# <トルコ政府連携協会
# 公立高校・公立大学
# 高校入試・大学
# [{'begin': 7095, 'end': 7102}, {'begin': 7147, 'end': 7157}, {'begin': 16550, 'end': 16559}, {'begin': 16612, 'end': 16619}]
# イスラム協会
# イスラム協会
# イスラム協会
# イスラム協会
# [{'begin': 5408, 'end': 5414}, {'begin': 6499, 'end': 6505}, {'begin': 6543, 'end': 6549}, {'begin': 11615, 'end': 11621}]
# []
# 単科大学
# アルジェ大学
# 国立アルジェ工科大学
# [{'begin': 9842, 'end': 9846}, {'begin': 9874, 'end': 9880}, {'begin': 9894, 'end': 9904}]
# コスタリカ国立大学
# コスタリカ大学
# 平和大学
# コスタリカ大学
# コスタリカ工科大学
# ナシオナル大学
# 国立遠隔大学
# [{'begin': 4014, 'end': 4023}, {'begin': 6143, 'end': 6150}, {'begin': 8707, 'end': 8711}, {'begin': 12005, 'end': 12012}, {'begin': 12049, 'end': 12058}, {'begin': 12067, 'end': 12074}, {'begin': 12082, 'end': 12088}]
# 京都大学
# 京都大学
# 中国人民解放軍国防大学
# アフリカ人権防衛協会
# [{'begin': 5712, 'end': 5716}, {'begin': 5717, 'end': 5721}, {'begin': 6151, 'end': 6162}, {'begin': 10210, 'end': 10220}]
# マリアン・ングアビ大学
# [{'begin': 1989, 'end': 2000}]
# []
# []
# []
# 国際沿療学会
# [{'begin': 10976, 'end': 10982}]
# キリロム工科大学
# [{'begin': 9020, 'end': 9028}]
# 国公立大学
# 難関大学
# メキシコ国立自治大学
# グアダラハラ大学
# モンテレイ工科大学
# 国公立大学
# メキシコ国立自治大学
# メキシコ連邦区ボクシング・レスリング協会
# [{'begin': 15241, 'end': 15246}, {'begin': 15357, 'end': 15361}, {'begin': 16705, 'end': 16715}, {'begin': 16723, 'end': 16731}, {'begin': 16739, 'end': 16748}, {'begin': 16772, 'end': 16777}, {'begin': 19625, 'end': 19635}, {'begin': 20924, 'end': 20944}]
# 日本サッカー協会
# 日本台湾交流協会
# 台湾日本関係協会
# 単科大学
# 総合大学
# 金日成総合大学
# 金策工業総合大学
# 平壌外国語大学
# [{'begin': 3000, 'end': 3008}, {'begin': 32358, 'end': 32366}, {'begin': 32367, 'end': 32375}, {'begin': 46653, 'end': 46657}, {'begin': 46664, 'end': 46668}, {'begin': 46689, 'end': 46696}, {'begin': 46706, 'end': 46714}, {'begin': 46724, 'end': 46731}]
# 日本放送協会
# 日本体育大学
# 日本大学
# 日本相撲協会
# 日本放送協会
# [{'begin': 1519, 'end': 1525}, {'begin': 1806, 'end': 1812}, {'begin': 1940, 'end': 1944}, {'begin': 1984, 'end': 1990}, {'begin': 22611, 'end': 22617}]
# []
# アブドゥ・ムムニ大学
# 旧ニアメ大学
# 4年・高校3年・大学
# 総合大学
# 旧ニアメ大学
# イスラム大学
# サイ・イスラム大学
# [{'begin': 2992, 'end': 3002}, {'begin': 3008, 'end': 3014}, {'begin': 9245, 'end': 9255}, {'begin': 9410, 'end': 9414}, {'begin': 9425, 'end': 9431}, {'begin': 9433, 'end': 9439}, {'begin': 9442, 'end': 9451}]
# []
# ハワイ大学
# [{'begin': 6277, 'end': 6282}]
# ココディ大学
# ダボボ・アジャメ大学
# 総合大学
# [{'begin': 8243, 'end': 8249}, {'begin': 8256, 'end': 8266}, {'begin': 8284, 'end': 8288}]
# []
# 南アフリカ放送協会
# ケープタウン大学
# プレトリア大学
# ステレンボッシュ大学
# ウィットウォータースランド大学
# ステレンボッシュ大学
# フリーステート大学
# 北西大学
# プレトリア大学
# [{'begin': 12779, 'end': 12788}, {'begin': 15137, 'end': 15145}, {'begin': 15146, 'end': 15153}, {'begin': 15154, 'end': 15164}, {'begin': 15165, 'end': 15180}, {'begin': 15189, 'end': 15199}, {'begin': 15200, 'end': 15209}, {'begin': 15210, 'end': 15214}, {'begin': 15215, 'end': 15222}]
# []
# 全米ライフル協会
# バージニア工科大学
# ニューヨーク州立大学
# [{'begin': 28600, 'end': 28608}, {'begin': 28905, 'end': 28914}, {'begin': 33063, 'end': 33073}]
# ザンビア大学
# カッパーベルト大学
# ザンビア大学
# [{'begin': 7857, 'end': 7863}, {'begin': 7870, 'end': 7879}, {'begin': 8037, 'end': 8043}]
# []
# []
# 秋野豊筑波大学
# [{'begin': 3869, 'end': 3876}]
# []
# []
# 「オマーン・日本友好協会
# [{'begin': 970, 'end': 982}]
# []
# ナイジェリア大学
# イバダン大学
# ラゴス大学
# [{'begin': 11785, 'end': 11793}, {'begin': 11801, 'end': 11807}, {'begin': 11815, 'end': 11820}]
# []
# []
# []
# []
# ルクセンブルク大学
# [{'begin': 8851, 'end': 8860}]
# クラクフ大学
# ヤギェウォ大学
# クラクフ大学
# クラクフ大学
# クラクフ大学
# ワルシャワ大学
# 同大学
# ポズナン大学
# ワルシャワ大学
# 国立大学
# [{'begin': 8014, 'end': 8020}, {'begin': 8021, 'end': 8028}, {'begin': 8651, 'end': 8657}, {'begin': 9533, 'end': 9539}, {'begin': 9746, 'end': 9752}, {'begin': 22835, 'end': 22842}, {'begin': 22857, 'end': 22860}, {'begin': 22996, 'end': 23002}, {'begin': 30616, 'end': 30623}, {'begin': 34899, 'end': 34903}]
# ロンドン伝道協会
# ロンドン宣教協会
# 国立大学
# 総合大学
# 工科大学
# ロンドン宣教協会
# [{'begin': 12039, 'end': 12047}, {'begin': 26010, 'end': 26018}, {'begin': 27299, 'end': 27303}, {'begin': 27391, 'end': 27395}, {'begin': 27396, 'end': 27400}, {'begin': 30891, 'end': 30899}]
# モントリオール理工科大学
# カナダサッカー協会
# [{'begin': 4683, 'end': 4695}, {'begin': 15703, 'end': 15712}]
# []
# ガンビア大学
# [{'begin': 4997, 'end': 5003}]
# []
# []
# ニカラグア国立自治大学
# 中米大学
# ニカラグア工科大学
# [{'begin': 11092, 'end': 11103}, {'begin': 11111, 'end': 11115}, {'begin': 11123, 'end': 11132}]
# 東海大学
# [{'begin': 9618, 'end': 9622}]
# []
# []
# []
# フィリピン大学
# フィリピン司教協会
# 聖トマス大学
# フィリピン大学
# [{'begin': 8367, 'end': 8374}, {'begin': 23863, 'end': 23872}, {'begin': 24226, 'end': 24232}, {'begin': 24296, 'end': 24303}]
# 企業・労組・農民・大学
# オランダ貿易協会
# 国際銀行間通信協会
# [{'begin': 3319, 'end': 3330}, {'begin': 6796, 'end': 6804}, {'begin': 16017, 'end': 16026}]
# 共和国大学
# [{'begin': 10541, 'end': 10546}]
# ザイトゥーナ大学
# チュニス大学
# カルタゴ大学
# エル・マナール大学
# [{'begin': 11192, 'end': 11200}, {'begin': 11206, 'end': 11212}, {'begin': 11219, 'end': 11225}, {'begin': 11232, 'end': 11241}]
# ロンドン大学
# [{'begin': 6673, 'end': 6679}]
# []
# ヴィリニュス大学
# カウナス工科大学
# カウナス医科大学
# ヴィータウタス・マグヌス大学
# 男子プロテニス協会
# [{'begin': 14959, 'end': 14967}, {'begin': 14980, 'end': 14988}, {'begin': 15000, 'end': 15008}, {'begin': 15020, 'end': 15034}, {'begin': 17744, 'end': 17753}]
# []
# []
# アディスアベバ大学
# [{'begin': 13252, 'end': 13261}]
# []
# 国立アスンシオン大学
# [{'begin': 11777, 'end': 11787}]
# []
# アゴスティーニョ・ネト大学
# アンゴラ・カトリック大学
# [{'begin': 10655, 'end': 10668}, {'begin': 10675, 'end': 10687}]
# ベイルート・アメリカン大学
# レバノン大学
# ベイルート・アメリカン大学
# [{'begin': 11627, 'end': 11640}, {'begin': 11648, 'end': 11654}, {'begin': 12911, 'end': 12924}]
# []
# []
# []
# オックスフォード大学
# タシュケント航空生産協会
# ウェストミンスター国際大学
# 国際クラッシュ協会
# [{'begin': 14363, 'end': 14373}, {'begin': 18198, 'end': 18210}, {'begin': 20393, 'end': 20406}, {'begin': 23339, 'end': 23348}]
# []
# 防衛大学
# 防衛大学
# [{'begin': 6044, 'end': 6048}, {'begin': 6089, 'end': 6093}]
# アル=アズハル大学
# 3年・高校3年・大学
# 主要大学
# アル=アズハル大学
# カイロ大学
# [{'begin': 14056, 'end': 14065}, {'begin': 15005, 'end': 15015}, {'begin': 15321, 'end': 15325}, {'begin': 15437, 'end': 15446}, {'begin': 15469, 'end': 15474}]
# 安南愛国者協会
# 防衛大学
# ハノイ自然科学大学
# 師範短期大学
# ベトナム青年連協会
# [{'begin': 5838, 'end': 5845}, {'begin': 11333, 'end': 11337}, {'begin': 21461, 'end': 21470}, {'begin': 31213, 'end': 31219}, {'begin': 32930, 'end': 32939}]
# []
# []
# 高校・大学
# マラヤ大学
# マレーシア国民大学
# マレーシア工科大学
# マレーシア科学大学
# マレーシアサインズ大学
# [{'begin': 3480, 'end': 3485}, {'begin': 14391, 'end': 14396}, {'begin': 14406, 'end': 14415}, {'begin': 14425, 'end': 14434}, {'begin': 14444, 'end': 14453}, {'begin': 14454, 'end': 14465}]
# 工科系大学
# サウジアラビア王立科学技術大学
# 総合大学
# [{'begin': 14557, 'end': 14562}, {'begin': 14571, 'end': 14586}, {'begin': 14736, 'end': 14740}]
# []
# []
# シェイク・アンタ・ジョップ大学
# 旧ダカール大学
# ガストン・ベルジェ大学
# ジガンショール大学
# [{'begin': 9022, 'end': 9037}, {'begin': 9046, 'end': 9053}, {'begin': 9055, 'end': 9066}, {'begin': 9076, 'end': 9085}]
# 西インド諸島大学
# [{'begin': 2249, 'end': 2257}]
# 西インド諸島大学
# ジャマイカ工科大学
# 北カリブ大学
# 西インド諸島大学
# [{'begin': 5388, 'end': 5396}, {'begin': 5404, 'end': 5413}, {'begin': 5421, 'end': 5427}, {'begin': 6406, 'end': 6414}]
# スウェーデン王立工科大学
# [{'begin': 11172, 'end': 11184}]
# サント・ドミンゴ自治大学
# マドレ・イ・マエストラ・カトリカ大学
# サンティアゴ工科大学
# サント・ドミンゴ自治大学
# [{'begin': 10026, 'end': 10038}, {'begin': 10046, 'end': 10064}, {'begin': 10072, 'end': 10082}, {'begin': 10097, 'end': 10109}]
# []
# 化学会
# [{'begin': 12416, 'end': 12419}]
# ノルウェーヒューマニスト協会
# [{'begin': 2588, 'end': 2602}]
# ガル・ユーニス大学
# トリポリ大学
# 元アル・ファテフ大学
# [{'begin': 8635, 'end': 8644}, {'begin': 8652, 'end': 8658}, {'begin': 8659, 'end': 8669}]
# NPO法人日本パラオ国際交友協会
# [{'begin': 8592, 'end': 8608}]
# バグダード音楽大学
# [{'begin': 22747, 'end': 22756}]
# []
# []
# シンガポール公衆衛生協会
# シンガポール国立大学
# シンガポール経営学院大学
# 京都大学
# 東京大学
# SIM大学
# [{'begin': 19001, 'end': 19013}, {'begin': 21005, 'end': 21015}, {'begin': 21032, 'end': 21044}, {'begin': 21305, 'end': 21309}, {'begin': 21314, 'end': 21318}, {'begin': 21368, 'end': 21373}]
# 友好協会
# [{'begin': 3188, 'end': 3192}]
# バレンシア大学
# サラマンカ大学
# サラマンカ大学
# マドリード・コンプルテンセ大学
# バリャドリード大学
# バルセロナ大学
# サンティアゴ・デ・コンポステーラ大学
# デウスト大学
# [{'begin': 4726, 'end': 4733}, {'begin': 4747, 'end': 4754}, {'begin': 27534, 'end': 27541}, {'begin': 27549, 'end': 27564}, {'begin': 27572, 'end': 27581}, {'begin': 27588, 'end': 27595}, {'begin': 27603, 'end': 27621}, {'begin': 27629, 'end': 27635}]
# ロンドン大学
# 国立大学
# [{'begin': 5683, 'end': 5689}, {'begin': 5695, 'end': 5699}]
# []
# 日本チベット学会
# ワシントン大学
# [{'begin': 420, 'end': 428}, {'begin': 737, 'end': 744}]
# []
# []
# []
# ウィスコンシン大学
# 国家重点大学
# 北京大学
# 清華大学
# トップ大学
# 北京大学
# 清華大学
# [{'begin': 29345, 'end': 29354}, {'begin': 30645, 'end': 30651}, {'begin': 30652, 'end': 30656}, {'begin': 30665, 'end': 30669}, {'begin': 30673, 'end': 30678}, {'begin': 30694, 'end': 30698}, {'begin': 30714, 'end': 30718}]
# []
# マラウイ大学
# マラウイ大学
# ムズズ大学
# [{'begin': 3793, 'end': 3799}, {'begin': 6097, 'end': 6103}, {'begin': 6110, 'end': 6115}]
# []
# 社団法人日本ネパール協会
# トリブバン大学
# カトマンズ大学
# [{'begin': 7038, 'end': 7050}, {'begin': 12471, 'end': 12478}, {'begin': 12492, 'end': 12499}]
# 米大手化学会
# [{'begin': 6388, 'end': 6394}]
# アル・カラウィーン大学
# ムハンマド5世大学
# [{'begin': 13115, 'end': 13126}, {'begin': 13133, 'end': 13142}]
# 筑波大学
# テヘラン大学
# アミール・キャビール工科大学
# アルザフラー大学
# イスラーム自由大学
# シャリーフ工科大学
# 4大学
# 単科大学
# 私学・イスラーム自由大学
# 通信教育大学
# 私学・イスラーム自由大学
# 2私学・イスラーム自由大学
# 他大学
# 3大学
# イラン・サッカー協会
# [{'begin': 17674, 'end': 17678}, {'begin': 24637, 'end': 24643}, {'begin': 24650, 'end': 24664}, {'begin': 24671, 'end': 24679}, {'begin': 24686, 'end': 24695}, {'begin': 24702, 'end': 24711}, {'begin': 25319, 'end': 25322}, {'begin': 25331, 'end': 25335}, {'begin': 25495, 'end': 25507}, {'begin': 25581, 'end': 25587}, {'begin': 25627, 'end': 25639}, {'begin': 25698, 'end': 25711}, {'begin': 25789, 'end': 25792}, {'begin': 25851, 'end': 25854}, {'begin': 29813, 'end': 29823}]
# []
# コインブラ大学
# コインブラ大学
# リスボン大学
# ポルト大学
# リスボン工科大学
# ポルトガル・カトリカ大学
# [{'begin': 1874, 'end': 1881}, {'begin': 16203, 'end': 16210}, {'begin': 16218, 'end': 16224}, {'begin': 16232, 'end': 16237}, {'begin': 16245, 'end': 16253}, {'begin': 16261, 'end': 16273}]
# []
# []
# []
# []
# []
# []
# マケレレ大学
# [{'begin': 8408, 'end': 8414}]
# []
# 放送大学
# 通信制公立大学
# オープン大学
# 4協会
# サッカー協会
# イングランドサッカー協会
# 地域協会
# 地域協会
# 地域協会
# 4協会
# 4協会
# [{'begin': 6534, 'end': 6538}, {'begin': 6546, 'end': 6553}, {'begin': 6556, 'end': 6562}, {'begin': 22545, 'end': 22548}, {'begin': 22798, 'end': 22804}, {'begin': 22868, 'end': 22880}, {'begin': 22898, 'end': 22902}, {'begin': 22995, 'end': 22999}, {'begin': 23132, 'end': 23136}, {'begin': 23188, 'end': 23191}, {'begin': 23225, 'end': 23228}]
# ベナディール大学
# ソマリア国立大学
# モガディシオ大学
# キスマヨ大学
# ゲド大学
# [{'begin': 7117, 'end': 7125}, {'begin': 7126, 'end': 7134}, {'begin': 7135, 'end': 7143}, {'begin': 7144, 'end': 7150}, {'begin': 7151, 'end': 7155}]
# 準大学
# 準大学
# エドゥアルド・モンドラーネ大学
# モザンビーク教育大学
# [{'begin': 9092, 'end': 9095}, {'begin': 9180, 'end': 9183}, {'begin': 9323, 'end': 9338}, {'begin': 9346, 'end': 9356}]
# []
# 「大学
# [{'begin': 10567, 'end': 10570}]
# サンマリノ共和国大学
# [{'begin': 5573, 'end': 5583}]
# []
# 国立大学
# [{'begin': 20017, 'end': 20021}]
# コルドバ大学
# 私立大学
# ブエノスアイレス大学
# コルドバ大学
# ラ・プラタ大学
# 国立工科大学
# ロサリオ大学
# アルゼンチン・カトリカ大学
# トルクァト・ディ・テラ大学
# [{'begin': 2694, 'end': 2700}, {'begin': 29788, 'end': 29792}, {'begin': 29810, 'end': 29820}, {'begin': 29828, 'end': 29834}, {'begin': 29842, 'end': 29849}, {'begin': 29857, 'end': 29863}, {'begin': 29871, 'end': 29877}, {'begin': 29885, 'end': 29898}, {'begin': 29906, 'end': 29919}]
# ホンジュラス国立自治大学
# [{'begin': 9828, 'end': 9840}]
# []
# 東京農業大学
# ジブチ大学
# [{'begin': 3252, 'end': 3258}, {'begin': 5706, 'end': 5711}]
# ナーランダ大学
# インド工科大学
# インド工科大学
# インド科学大学
# クイーンズランド大学
# 進歩主義作家協会
# インド・クリケット協会
# [{'begin': 3705, 'end': 3712}, {'begin': 10247, 'end': 10254}, {'begin': 23879, 'end': 23886}, {'begin': 23887, 'end': 23894}, {'begin': 32277, 'end': 32287}, {'begin': 41566, 'end': 41574}, {'begin': 42988, 'end': 42999}]
# リュブリャナ大学
# リュブリャナ大学
# マリボル大学
# [{'begin': 5420, 'end': 5428}, {'begin': 9212, 'end': 9220}, {'begin': 9221, 'end': 9227}]
# ベルリン大学
# ウィーン大学
# 東京帝国大学
# ドイツ研究センターヘルムホルツ協会
# フラウンホーファー協会
# 州立大学
# [{'begin': 15675, 'end': 15681}, {'begin': 15701, 'end': 15707}, {'begin': 15733, 'end': 15739}, {'begin': 21305, 'end': 21322}, {'begin': 21323, 'end': 21334}, {'begin': 27319, 'end': 27323}]
# UAE大学
# 国立大学
# 私立大学
# [{'begin': 9410, 'end': 9415}, {'begin': 9430, 'end': 9434}, {'begin': 9446, 'end': 9450}]
# []
# ハルキウ大学
# [{'begin': 10811, 'end': 10817}]
# 国立リベリア大学
# カッティントン大学
# 工科大学
# ウィリアム・V・S・タブマン大学
# 通信教育機関アダム・スミス大学
# アメリカ植民地協会
# [{'begin': 8638, 'end': 8646}, {'begin': 8657, 'end': 8666}, {'begin': 8667, 'end': 8671}, {'begin': 8672, 'end': 8688}, {'begin': 8750, 'end': 8765}, {'begin': 8891, 'end': 8900}]
# 総合大学
# エリート大学
# パリ大学
# モンペリエ大学
# エクス=マルセイユ大学
# ストラスブール大学
# リヨン大学
# パリ・カトリック大学
# [{'begin': 31195, 'end': 31199}, {'begin': 31228, 'end': 31234}, {'begin': 31257, 'end': 31261}, {'begin': 31269, 'end': 31276}, {'begin': 31284, 'end': 31295}, {'begin': 31303, 'end': 31312}, {'begin': 31320, 'end': 31325}, {'begin': 31333, 'end': 31343}]
# 日本新聞協会
# 国立アボメ・カラビ大学
# 国立パラク大学
# [{'begin': 386, 'end': 392}, {'begin': 4551, 'end': 4562}, {'begin': 4563, 'end': 4570}]
# []
# ティモール社会民主協会
# [{'begin': 1779, 'end': 1790}]
# 奴隷貿易廃止促進協会
# フォーラーベイ大学
# 教会宣教師協会
# フォーラーベイ大学
# ダラム大学
# シエラレオネ大学
# 同大学
# [{'begin': 1207, 'end': 1217}, {'begin': 1818, 'end': 1827}, {'begin': 7088, 'end': 7095}, {'begin': 7123, 'end': 7132}, {'begin': 7149, 'end': 7154}, {'begin': 7165, 'end': 7173}, {'begin': 7202, 'end': 7205}]
# エルサルバドル大学
# 国立大学
# [{'begin': 8138, 'end': 8147}, {'begin': 8161, 'end': 8165}]
# サン・マルコス大学
# ペルー・カトリカ大学
# 太平洋大学
# [{'begin': 16959, 'end': 16968}, {'begin': 16975, 'end': 16985}, {'begin': 16986, 'end': 16991}]
# []
# ボツワナ大学
# [{'begin': 10407, 'end': 10413}]
# []
# ジャン=ベデル・ボカサ大学
# [{'begin': 1359, 'end': 1372}]
# []
# []
# []
# []
# パナマ大学
# パナマ工科大学
# 世界ボクシング協会
# [{'begin': 9727, 'end': 9732}, {'begin': 9740, 'end': 9747}, {'begin': 10500, 'end': 10509}]
# []
# キューバ創価学会
# ハバナ大学
# [{'begin': 20707, 'end': 20715}, {'begin': 21080, 'end': 21085}]
# ルワンダ国立大学
# [{'begin': 6904, 'end': 6912}]
